# %% [markdown]
# <a href="https://colab.research.google.com/github/BoYeonJang/ICT-AI-education/blob/main/(8%EC%9B%94%209%EC%9D%BC)%20%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9D%84%20%ED%99%9C%EC%9A%A9%ED%95%9C%20%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%20%EB%AA%A8%EB%8D%B8%20%EB%A7%8C%EB%93%A4%EA%B8%B0(1)/BeautifulSoup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BeautifulSoup 기초

# %% [markdown]
# ## BeautifulSoup 특징
#
# - HTML과 XML 파일에서 데이터를 뽑아내기 위한 파이썬 라이브러리
# - HTML과 XML의 트리 구조를 탐색, 검색, 변경 가능
# - 다양한 파서(Parser)를 선택하여 이용 가능

# %% [markdown]
# ## HTML 파싱(Parsing)
#
# ### 웹페이지 예제 생성

# %%
# %%writefile example.html
# <!DOCTYPE html>
# <html>
#   <head>
#     <title> Page Title </title>
#   </head>
#   <body>
#     <h1> Heading </h1>
#     <p> Paragraph </p>
#     <div>
#       <a href = "www.google.com"> google </a>
#     </div>
#     <div class = "class1">
#       <p> a </p>
#       <a href = "www.naver.com"> naver </a>
#       <p> b </p>
#       <p> c </p>
#     </div>
#     <div id = "id1">
#       Example page
#       <p> g </p>
#     </div>
#   </body>
# </html>
# Out:
# Writing example.html

# %%
<!DOCTYPE html>
<html>
  <head>
    <title> </title>
  </head>
  <body>
    <a> </a>
  </body>
</html>
# Out:
#   File "<ipython-input-3-187c6c9ae5d2>", line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax

# %%
from bs4 import BeautifulSoup
import urllib.request

with open ("example.html") as fp:
  soup = BeautifulSoup(fp, 'html.parser')

# %% [markdown]
# ## HTML 태그 파싱

# %%
soup.title
# Out:
# <title> Page Title </title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# ' Page Title '

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.h1
# Out:
# <h1> Heading </h1>

# %%
soup.p
# Out:
# <p> Paragraph </p>

# %%
soup.div
# Out:
# <div>
# <a href="www.google.com"> google </a>
# </div>

# %%
soup.a
# Out:
# <a href="www.google.com"> google </a>

# %% [markdown]
# ## HTML 태그 검색
#
# - find(): 해당 조건에 맞는 하나의 태그를 가져옴
# - fina_all(): 해당 조건에 맞는 모든 태그를 가져옴
# - select(): CSS 선택자와 같은 형식으로 선택 가능

# %% [markdown]
# # 인터넷 웹페이지 가져오기

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

res_comic = requests.get('https://comic.naver.com/index')
soup_comic = BeautifulSoup(res_comic.text, 'lxml')

soup_comic
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <title>네이버 웹툰</title>
# <meta content="네이버 웹툰" property="og:title"/>
# <meta content="https://ssl.pstatic.net/static/comic/images/og_tag_v2.png" property="og:image"/>
# <meta content="매일매일 새로운 재미, 네이버 웹툰." property="og:description"/>
# <meta content="https://comic.naver.com/index" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="네이버 웹툰" property="og:article:author"/>
# <meta content="https://comic.naver.com" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/static/comic/favicon/webtoon_favicon_32x32.ico" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">function windowOpen(url){location.href = url;}function goArtistTitle(element, area, titleId, index, event) {nclk_v2(event,area,'',index);return artistAction.viewArtist(titleId, element);}</script>
# <script type="text/javascript">
#         var g_ssc = "comic.home";
#         var ccsrv = "cc.naver.com";
# 	</script>
# <script src="/aggregate/javascript/release/comic_main_20220803135648.js" type="text/javascript"></script>
# <link href="/css/comic/comic_20220803135648.css" rel="stylesheet" style="text/css"/>
# <script src="/aggregate/javascript/release/comic_gnb_20220803135648.js" type="text/javascript"></script>
# </head>
# <body onload="">
# <div class="end_page" id="wrap">
# <div id="u_skip">
# <a href="#menu" onclick="document.getElementById('menu').tabIndex=-1;document.getElementById('menu').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#content" onclick="document.getElementById('content').tabIndex=-1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <div id="header_wrap">
# <div id="header">
# <div id="gnb">
# <script type="text/javascript">
#         var gnb_option = {
#             gnb_service : "comic",
#             gnb_logout :  encodeURIComponent(window.location.href),
#             gnb_login :   encodeURIComponent(window.location.href),
#             gnb_template : "gnb_utf8",
#             gnb_brightness : 1,
#             gnb_item_hide_option: 0
#         };
#     </script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8?20220803135648" type="text/javascript"></script>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="gnb_naver" href="https://www.naver.com" onclick="nclk_v2(event,'STA.naverlogo')" title="NAVER">NAVER</a>
# <a class="gnb_comic" href="/index" onclick="nclk_v2(event,'STA.comic')" title="웹툰">웹툰</a>
# <em class="bar">|</em>
# <a class="gnb_novel" href="https://novel.naver.com" onclick="nclk_v2(event,'STA.novel')" title="웹소설">웹소설</a>
# <em class="bar">|</em>
# <a class="gnb_series" href="https://series.naver.com" onclick="nclk_v2(event,'STA.series')" title="시리즈">시리즈</a>
# </h1>
# <form action="/search" id="searchForm" method="get" name="search">
# <fieldset>
# <legend>검색</legend>
# <div class="snb_search_box">
# <!-- [D] 클릭시 label.ph 텍스트 삭제해주세요. -->
# <label class="ph" for="gnb.keyword">제목 / 작가로 검색할 수 있습니다.</label>
# <input class="snb_search_text" id="gnb.keyword" maxlength="18" name="keyword" title="검색어 입력" type="text" value=""/>
# <button alt="검색" class="btn_search" id="search_bar_button" onclick="nclk_v2(event,'STA.search')" title="검색" type="button"><span class="Nico_search">검색</span></button>
# </div>
# </fieldset>
# </form>
# </div>
# <div id="author_layer" style="text-align:left; display:none;">
# <ul id="author_layer_inner"> </ul>
# </div>
# <div class="notice_info">
# <span class="blind">공지사항</span>
# <div class="rolling">
# <div class="notice_rolling">
# <li>
# <a href="https://comic.naver.com/webtoon/list.nhn?titleId=798622" onclick="nclk_v2(event,'STA.txt')" title="하늘액션 서바이벌 &lt;천상의 주인&gt;">
# <span class="Nico_notice"></span>
# 										하늘액션 서바이벌 &lt;천상의 주인&gt;
# 									</a>
# </li>
# </div>
# </div>
# </div>
# </div>
# <div id="menu">
# <ul class="menu">
# <!-- [D] 선택된 li에 current 클래스 추가 -->
# <li class="current"><a href="/index" onclick="nclk_v2(event,'LNB.home');"><span class="Ntxt_home">웹툰 홈</span></a></li>
# <li><a href="/webtoon/weekday" onclick="nclk_v2(event,'LNB.toon');"><span class="Ntxt_webtoon">웹툰</span></a></li>
# <li><a href="/genre/bestChallenge" onclick="nclk_v2(event,'LNB.best');"><span class="Ntxt_best_challenge">베스트 도전</span></a></li>
# <li><a href="/genre/challenge" onclick="nclk_v2(event,'LNB.chal');"><span class="Ntxt_challenge_comic">도전만화</span></a></li>
# <li><a href="/mypage/favorite" onclick="nclk_v2(event,'LNB.my');"><span class="Ntxt_mypage">마이페이지</span></a></li>
# </ul>
# <h2 class="blind">웹툰 홈</h2>
# </div>
# <!-- //상단 메뉴 /index-->
# </div>
# <!-- 상단 영역(메인에만 나감.) -->
# <div class="mainTopArea">
# <div class="main_spot" id="mainNavi">
# <div class="data_area">
# <h2 class="Ntxt_today_webtoon">오늘의 웹툰</h2>
# <p class="date" id="curDate"></p>
# <!-- [D] 클릭된 이미지 a에 class="sel" 추가 -->
# <ul id="listMenu">
# <li><a href="javascript:void(0);" onclick="nclk_v2(event,'twt.byuser')"><span class="Ntxt_popular">인기순</span></a></li>
# <li><a href="javascript:void(0);" onclick="nclk_v2(event,'twt.byupdate')"><span class="Ntxt_update">업데이트순</span></a></li>
# <li><a href="javascript:void(0);" onclick="nclk_v2(event,'twt.byview')"><span class="Ntxt_count">조회순</span></a></li>
# <li><a href="javascript:void(0);" onclick="nclk_v2(event,'twt.byscore')"><span class="Ntxt_star_rate">별점순</span></a></li>
# </ul>
# </div>
# <h3 class="blind" id="mainTopAreaBlindOrder"></h3>
# <div class="webtoon_area">
# <div class="bigimg">
# <a class="_bigImgLink" href="javascript:void(0)" onclick="nclk_v2(event,'twt.main')">
# <img alt="static_img_comic" class="_bigImg" height="195" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif" width="582"/>
# <span class="bd"></span>
# <span class="mark_adult_big" id="ageRateBig" style="display: none">18세 이상 이용 가능</span>
# </a>
# </div>
# <div class="webtoon_lst">
# <div class="lst_area">
# <ul id="comicList"></ul>
# </div>
# <!-- [D] 클릭된 화살이미지 span에 class="sel" 추가 -->
# <a class="btn_prev" href="javascript:void(0)" onclick="nclk_v2(event,'twt.prev')"><span class="btn_prev_arr">이전</span></a>
# <a class="btn_next" href="javascript:void(0)" onclick="nclk_v2(event,'twt.next')"><span class="btn_next_arr">다음</span></a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 		var ts = new nts.Comic.MainNavi();
# 	</script>
# <div class="todayChallenge">
# <h4 class="Ntxt_new_best">새로운 베스트 도전만화</h4>
# <p class="best_photo">
# <a href="/bestChallenge/list?titleId=797176" onclick="nclk_v2(event,'new.thum','797176')">
# <img alt="신혼식물" height="110" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2022/07/21/328744/thumbnail_218x120353026b1_1c22_4c2e_925f_6a092e7fbb32_00001546.JPEG" width="202"/>
# <span class="mask"></span>
# </a>
# </p>
# <dl>
# <!-- [D] 제목부분: 공백포함 10자 이상 초과시 말줄임 표시 해주세요.  아이디 부분: 공백포함 7자 이상 초과시 말줄임 표시 해주세요. -->
# <!-- [D] IE 스펙의 이슈로 글자 수가 아닌 width로 말줄임 자동 표시. -->
# <dt>
# <a class="challenge_title" href="/bestChallenge/list?titleId=797176" onclick="nclk_v2(event,'new.title','797176')">
# 					신혼식물
# 				</a>
# <span>
# <a class="challenge_id" href="#" onclick="nclk_v2(event,'new.author'); return artistAction.viewArtist(797176, this);">
# 						momo****
# 					</a>
# </span>
# </dt>
# <!-- [D] 세줄 초과시 말줄임 표시 해주세요.-->
# <dd class="ellipsis_content" style="height: 54px;">
# <a href="/bestChallenge/list?titleId=797176" onclick="nclk_v2(event,'new.text','797176')">
#
#
# 					태초의 지구에는...원시인...아니 식물인간이 살았다! (격일 업데이트 : 평일 밤 9시 / 주말 아침 9시)
#
# 				</a>
# </dd>
# </dl>
# </div>
# </div>
# <script type="text/javascript">
# 	(function ellipsis() {
# 		var wel = $Element($$.getSingle("dd.ellipsis_content a"));
# 		var sParent = $Element($$.getSingle("dd.ellipsis_content"));
#
# 		if (!wel || !sParent) {
# 			return;
# 		}
#
# 		var sText = wel.text();
# 		var sLength = sText.length;
#
# 		for(var count = 1; count <= sLength; count++) {
# 			if (wel.height() > sParent.height()) {
# 				var cutText = sText.slice(0, count * (-1));
# 				wel.text(cutText + ' . . .');
# 			} else {
# 				break;
# 			}
# 		}
# 	})();
# </script>
# <!-- //상단 영역 -->
# <div class="" id="container">
# <div class="" id="content">
# <!-- body -->
# <div class="ad_banner_premium" data-ad-banner="premium_banner"></div>
# <!-- 장르별 추천 웹툰 -->
# <div class="genreRecomBox">
# <h3 class="titleMain">
# <a href="#" id="moreGenre" onclick="nclk_v2(event,'rtb.more')"><span class="Ntxt_genre_webtoon">장르별 추천웹툰</span></a>
# </h3>
# <div class="tab_gr">
# <ul>
# <!-- [D] 선택된 li에 on 클래스 추가 -->
# <li><a href="#" id="episode" title="에피소드">에피소드</a></li>
# <li class="on"><a href="#" id="omnibus" title="옴니버스">옴니버스</a></li>
# <li><a href="#" id="story" title="스토리">스토리</a>
# <span class="bar"></span>
# </li>
# <li><a href="#" id="daily" title="일상">일상</a></li>
# <li><a href="#" id="comic" title="개그">개그</a></li>
# <li><a href="#" id="fantasy" title="판타지">판타지</a></li>
# <li><a href="#" id="action" title="액션">액션</a></li>
# <li><a href="#" id="drama" title="드라마">드라마</a></li>
# <li><a href="#" id="pure" title="순정">순정</a></li>
# <li><a href="#" id="sensibility" title="감성">감성</a></li>
# <li><a href="#" id="thrill" title="스릴러">스릴러</a></li>
# <li><a href="#" id="historical" title="무협/사극">무협/사극</a></li>
# <li><a href="#" id="sports" title="스포츠">스포츠</a></li>
# </ul>
# </div>
# <div class="view_type">
# <ul class="sortby">
# <li><a href="#" id="User" onclick="nclk_v2(event,'rtb.byuser')"><span class="Ntxt_popular">인기순</span></a></li>
# <li class="sel"><a href="#" id="Update" onclick="nclk_v2(event,'rtb.upd')"><span class="Ntxt_update">업데이트순</span></a></li>
# <li><a href="#" id="ViewCount" onclick="nclk_v2(event,'rtb.cnt')"><span class="Ntxt_count">조회순</span></a></li>
# <li><a href="#" id="StarScore" onclick="nclk_v2(event,'rtb.sta')"><span class="Ntxt_star_rate">별점순</span></a></li>
# </ul>
# </div>
# <h3 class="blind" id="mainGenreBlind">옴니버스 - 업데이트순</h3>
# <ul class="genreRecom" id="genreRecommand">
# <li>
# <div class="genreRecomImg2">
# <a href="/webtoon/list?titleId=785703" onclick="nclk_v2(event,'rcn*o.thum','785703','1')">
# <span class="mask"></span>
# <img alt="애옹식당" height="120" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/785703/thumbnail/thumbnail_IMAG04_bece7723-5efa-48cf-ab7e-61a4c7b83f77.jpg" title="애옹식당" width="218"/>
# </a>
# </div>
# <div class="genreRecomInfo2">
# <h6 class="title">
# <span class="ico_break" style="display:none;">휴재</span>
# <span class="ico_cut">컷툰</span>
# <span class="ico_short_ani" style="display:none;">숏애니</span>
# <a href="/webtoon/list?titleId=785703" onclick="nclk_v2(event,'rcn*o.title','785703','1')">
# <span>애옹식당</span>
# </a>
# </h6>
# <p>
# <a href="/webtoon/detail?titleId=785703&amp;no=35" onclick="nclk_v2(event,'rcn*o.sub','785703','1')">
# <span>34화 검은 고양이와의 인연(2)</span>
# </a>
# </p>
# <span class="user">
# <a href="#" onclick="return goArtist('785703', '1', this, event);">
# 								정다정
# 							</a>
# </span>
# </div>
# </li>
# <li>
# <div class="genreRecomImg2">
# <a href="/webtoon/list?titleId=783529" onclick="nclk_v2(event,'rcn*o.thum','783529','2')">
# <span class="mask"></span>
# <img alt="미물" height="120" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/783529/thumbnail/thumbnail_IMAG04_2d6518b0-9934-4b16-b1a6-9660d2d3b1b2.jpg" title="미물" width="218"/>
# </a>
# </div>
# <div class="genreRecomInfo2">
# <h6 class="title">
# <span class="ico_break" style="display:none;">휴재</span>
# <span class="ico_cut" style="display:none;">컷툰</span>
# <span class="ico_short_ani" style="display:none;">숏애니</span>
# <a href="/webtoon/list?titleId=783529" onclick="nclk_v2(event,'rcn*o.title','783529','2')">
# <span>미물</span>
# </a>
# </h6>
# <p>
# <a href="/webtoon/detail?titleId=783529&amp;no=27" onclick="nclk_v2(event,'rcn*o.sub','783529','2')">
# <span>27화 벌레들의 밤 (2)</span>
# </a>
# </p>
# <span class="user">
# <a href="#" onclick="return goArtist('783529', '2', this, event);">
# 								외눈박이 / 김도연
# 							</a>
# </span>
# </div>
# </li>
# <li>
# <div class="genreRecomImg2">
# <a href="/webtoon/list?titleId=21815" onclick="nclk_v2(event,'rcn*o.thum','21815','3')">
# <span class="mask"></span>
# <img alt="히어로메이커" height="120" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/21815/thumbnail/thumbnail_title_21815_218x120.gif" title="히어로메이커" width="218"/>
# </a>
# </div>
# <div class="genreRecomInfo2">
# <h6 class="title">
# <span class="ico_break" style="display:none;">휴재</span>
# <span class="ico_cut" style="display:none;">컷툰</span>
# <span class="ico_short_ani" style="display:none;">숏애니</span>
# <a href="/webtoon/list?titleId=21815" onclick="nclk_v2(event,'rcn*o.title','21815','3')">
# <span>히어로메이커</span>
# </a>
# </h6>
# <p>
# <a href="/webtoon/detail?titleId=21815&amp;no=834" onclick="nclk_v2(event,'rcn*o.sub','21815','3')">
# <span>거품</span>
# </a>
# </p>
# <span class="user">
# <a href="#" onclick="return goArtist('21815', '3', this, event);">
# 								빤쓰
# 							</a>
# </span>
# </div>
# </li>
# <li>
# <div class="genreRecomImg2">
# <a href="/webtoon/list?titleId=741891" onclick="nclk_v2(event,'rcn*o.thum','741891','4')">
# <span class="mask"></span>
# <img alt="결혼생활 그림일기" height="120" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/741891/thumbnail/thumbnail_IMAG04_c2879c7f-6c52-410c-91f3-77fffe6d3335.jpg" title="결혼생활 그림일기" width="218"/>
# </a>
# </div>
# <div class="genreRecomInfo2">
# <h6 class="title">
# <span class="ico_break" style="display:none;">휴재</span>
# <span class="ico_cut" style="display:none;">컷툰</span>
# <span class="ico_short_ani" style="display:none;">숏애니</span>
# <a href="/webtoon/list?titleId=741891" onclick="nclk_v2(event,'rcn*o.title','741891','4')">
# <span>결혼생활 그림일기</span>
# </a>
# </h6>
# <p>
# <a href="/webtoon/detail?titleId=741891&amp;no=127" onclick="nclk_v2(event,'rcn*o.sub','741891','4')">
# <span>126화 하는 김에 1</span>
# </a>
# </p>
# <span class="user">
# <a href="#" onclick="return goArtist('741891', '4', this, event);">
# 								은꼼지
# 							</a>
# </span>
# </div>
# </li>
# <li>
# <div class="genreRecomImg2">
# <a href="/webtoon/list?titleId=771933" onclick="nclk_v2(event,'rcn*o.thum','771933','5')">
# <span class="mask"></span>
# <img alt="굿 리스너" height="120" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/771933/thumbnail/thumbnail_IMAG04_5cff8800-a799-4db6-aae3-1656e1fdb664.jpg" title="굿 리스너" width="218"/>
# </a>
# </div>
# <div class="genreRecomInfo2">
# <h6 class="title">
# <span class="ico_break" style="display:none;">휴재</span>
# <span class="ico_cut" style="display:none;">컷툰</span>
# <span class="ico_short_ani" style="display:none;">숏애니</span>
# <a href="/webtoon/list?titleId=771933" onclick="nclk_v2(event,'rcn*o.title','771933','5')">
# <span>굿 리스너</span>
# </a>
# </h6>
# <p>
# <a href="/webtoon/detail?titleId=771933&amp;no=66" onclick="nclk_v2(event,'rcn*o.sub','771933','5')">
# <span>후기</span>
# </a>
# </p>
# <span class="user">
# <a href="#" onclick="return goArtist('771933', '5', this, event);">
# 								쥬드프라이데이
# 							</a>
# </span>
# </div>
# </li>
# <li>
# <div class="genreRecomImg2">
# <a href="/webtoon/list?titleId=695796" onclick="nclk_v2(event,'rcn*o.thum','695796','6')">
# <span class="mask"></span>
# <img alt="내일" height="120" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/695796/thumbnail/thumbnail_IMAG04_b23fb9da-dd9e-4c7e-9808-141ae79b6458.jpg" title="내일" width="218"/>
# </a>
# </div>
# <div class="genreRecomInfo2">
# <h6 class="title">
# <span class="ico_break" style="display:none;">휴재</span>
# <span class="ico_cut" style="display:none;">컷툰</span>
# <span class="ico_short_ani" style="display:none;">숏애니</span>
# <a href="/webtoon/list?titleId=695796" onclick="nclk_v2(event,'rcn*o.title','695796','6')">
# <span>내일</span>
# </a>
# </h6>
# <p>
# <a href="/webtoon/detail?titleId=695796&amp;no=261" onclick="nclk_v2(event,'rcn*o.sub','695796','6')">
# <span>260화 어른 (19)</span>
# </a>
# </p>
# <span class="user">
# <a href="#" onclick="return goArtist('695796', '6', this, event);">
# 								라마
# 							</a>
# </span>
# </div>
# </li>
# </ul>
# </div>
# <!-- //장르별 추천 웹툰 -->
# <!-- 베스트&도전 추천만화 -->
# <div class="genreRecomBox_area">
# <h3 class="titleMain"><span class="Ntxt_best">베스트도전&amp;도전 추천</span></h3>
# <ul class="genreRecom">
# <li>
# <h4 class="subtlt3">에피소드</h4>
# <ul class="genreRecomList">
# <li>
# <div class="genreRecomImg">
# <a href="/bestChallenge/list?titleId=703099" onclick="nclk_v2(event,'sug.thum');">
# <img alt="일상견문록" height="90" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2020/08/04/313585/thumbnail_83x908d1b0ff6_f79d_4909_8fec_47088b3611e5_00002095.JPEG" title="일상견문록" width="83"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo">
# <h6 class="title"><a href="/bestChallenge/list?titleId=703099" onclick="nclk_v2(event,'sug.title');">일상견문록</a></h6>
# <div><a class="user" href="#" onclick="return goArtistTitle(this,'sug.artist','703099','1',event);">jaem****</a></div>
# <div class="summary">해외 여행 일상툰</div>
# <div class="rating_type">
# <span class="star"><em style="width:98%" title="점">평점</em></span>
# <strong>9.89</strong>
# </div>
# </div>
# </li>
# <li>
# <div class="genreRecomImg">
# <a href="/bestChallenge/list?titleId=794107" onclick="nclk_v2(event,'sug.thum');">
# <img alt="임신해서그래" height="90" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2022/04/27/355337/thumbnail_83x90aaad4147_6f71_4801_896a_40f8402b47f7_00002801.JPEG" title="임신해서그래" width="83"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo">
# <h6 class="title"><a href="/bestChallenge/list?titleId=794107" onclick="nclk_v2(event,'sug.title');">임신해서그래</a></h6>
# <div><a class="user" href="#" onclick="return goArtistTitle(this,'sug.artist','794107','2',event);">iiii****</a></div>
# <div class="summary">임산부 공감툰</div>
# <div class="rating_type">
# <span class="star"><em style="width:94%" title="점">평점</em></span>
# <strong>9.49</strong>
# </div>
# </div>
# </li>
# <li>
# <div class="genreRecomImg">
# <div class="cutTypeChal"><span>도전</span></div>
# <a href="/challenge/list?titleId=719943" onclick="nclk_v2(event,'sug.ecthum');">
# <img alt="알루툰" height="90" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2022/06/13/310694/thumbnail_83x90330bedae_4000_4fc6_b999_d54f1e8f34aa_00003349.JPEG" title="알루툰" width="83"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo">
# <h6 class="title"><a href="/challenge/list?titleId=719943" onclick="nclk_v2(event,'sug.ectitle');">알루툰</a></h6>
# <div><a class="user" href="#" onclick="return goArtistTitle(this,'sug.ecartist','719943','3',event);">qpfj****</a></div>
# <div class="summary">개그 일상툰</div>
# <div class="rating_type">
# <span class="star"><em style="width:96%" title="점">평점</em></span>
# <strong>9.67</strong>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <h4 class="subtlt3">옴니버스</h4>
# <ul class="genreRecomList">
# <li>
# <div class="genreRecomImg">
# <a href="/bestChallenge/list?titleId=797176" onclick="nclk_v2(event,'sug.ecthum');">
# <img alt="신혼식물" height="90" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2022/07/21/328744/thumbnail_83x90e008a344_d95b_4aac_ac42_32d1131eed72_00001553.JPEG" title="신혼식물" width="83"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo">
# <h6 class="title"><a href="/bestChallenge/list?titleId=797176" onclick="nclk_v2(event,'sug.ectitle');">신혼식물</a></h6>
# <div><a class="user" href="#" onclick="return goArtistTitle(this,'sug.ecartist','797176','1',event);">momo****</a></div>
# <div class="summary">원시식물인간</div>
# <div class="rating_type">
# <span class="star"><em style="width:98%" title="점">평점</em></span>
# <strong>9.88</strong>
# </div>
# </div>
# </li>
# <li class="first2">
# <div class="genreRecomImg">
# <a href="/bestChallenge/list?titleId=773869" onclick="nclk_v2(event,'sug.ecthum');">
# <img alt="누나미워!" height="90" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2021/05/31/346652/thumbnail_83x902882e0c9_0fef_4051_aa96_e0c354701b37_00000031.JPEG" title="누나미워!" width="83"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo">
# <h6 class="title"><a href="/bestChallenge/list?titleId=773869" onclick="nclk_v2(event,'sug.ectitle');">누나미워!</a></h6>
# <div><a class="user" href="#" onclick="return goArtistTitle(this,'sug.ecartist','773869','2',event);">good****</a></div>
# <div class="summary">누나와 동생의 일상</div>
# <div class="rating_type">
# <span class="star"><em style="width:98%" title="점">평점</em></span>
# <strong>9.90</strong>
# </div>
# </div>
# </li>
# <li class="first2">
# <div class="genreRecomImg">
# <div class="cutTypeChal">도전</div>
# <a href="/challenge/list?titleId=784181" onclick="nclk_v2(event,'sug.octhum');">
# <img alt="비틀비틀동화" height="90" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2022/05/25/350849/thumbnail_83x9014904281_e523_4002_bf1d_e87dbda97040_00000015.JPEG" title="비틀비틀동화" width="83"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo">
# <h6 class="title"><a href="/challenge/list?titleId=784181" onclick="nclk_v2(event,'sug.octitle');">비틀비틀동화</a></h6>
# <div><a class="user" href="#" onclick="return goArtistTitle(this,'sug.ocartist','784181','3',event);">atlk****</a></div>
# <div class="summary">동화 비틀기</div>
# <div class="rating_type">
# <span class="star"><em style="width:81%" title="점">평점</em></span>
# <strong>8.18</strong>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <h4 class="subtlt3">스토리</h4>
# <ul class="genreRecomList">
# <li>
# <div class="genreRecomImg">
# <a href="/bestChallenge/list?titleId=783797" onclick="nclk_v2(event,'sug.octhum');">
# <img alt="클로지오" height="90" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2022/04/23/350668/thumbnail_83x909cf1d546_f499_4757_8a62_314e08a01188_00001824.JPEG" title="클로지오" width="83"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo">
# <h6 class="title"><a href="/bestChallenge/list?titleId=783797" onclick="nclk_v2(event,'sug.octitle');">클로지오</a></h6>
# <div><a class="user" href="#" onclick="return goArtistTitle(this,'sug.ocartist','783797','1',event);">seoh****</a></div>
# <div class="summary">기억조각모음</div>
# <div class="rating_type">
# <span class="star"><em style="width:88%" title="점">평점</em></span>
# <strong>8.85</strong>
# </div>
# </div>
# </li>
# <li>
# <div class="genreRecomImg">
# <a href="/bestChallenge/list?titleId=729586" onclick="nclk_v2(event,'sug.octhum');">
# <img alt="소환진이 좀 이상해 보이는 건 기분 탓이겠지" height="90" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2021/09/28/325953/thumbnail_83x902043d341_40da_4026_a8da_20171dd1d2be_00004714.JPEG" title="소환진이 좀 이상해 보이는 건 기분 탓이겠지" width="83"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo">
# <h6 class="title"><a href="/bestChallenge/list?titleId=729586" onclick="nclk_v2(event,'sug.octitle');">소환진이 좀 이상해 보이는 건 기분 탓이겠지</a></h6>
# <div><a class="user" href="#" onclick="return goArtistTitle(this,'sug.ocartist','729586','2',event);">ssim****</a></div>
# <div class="summary">판타지!</div>
# <div class="rating_type">
# <span class="star"><em style="width:99%" title="점">평점</em></span>
# <strong>9.94</strong>
# </div>
# </div>
# </li>
# <li>
# <div class="genreRecomImg">
# <div class="cutTypeChal">도전</div>
# <a href="/challenge/list?titleId=773061" onclick="nclk_v2(event,'sug.scthum');">
# <img alt="의식의 흐름대로" height="90" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2021/05/28/346300/thumbnail_83x90bd9c262b_da3f_46de_8dac_f91ed5fa10ae_00001085.JPEG" title="의식의 흐름대로" width="83"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo">
# <h6 class="title"><a href="/challenge/list?titleId=773061" onclick="nclk_v2(event,'sug.sctitle');">의식의 흐름대로</a></h6>
# <div><a class="user" href="#" onclick="return goArtistTitle(this,'sug.scartist','773061','3',event);">dada****</a></div>
# <div class="summary">사람들의성장 이야기</div>
# <div class="rating_type">
# <span class="star"><em style="width:89%" title="점">평점</em></span>
# <strong>8.93</strong>
# </div>
# </div>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <!-- // 베스트&도전 추천만화 -->
# <!-- 장르별 인기 유료 만화(업데이트순) -->
# <div class="genreRecomBox_area" id="updateCompositionContent">
# <h3 class="titleMain">
# <span class="Ntxt_genre_popular">장르별 인기 단행본만화</span>
# </h3>
# <ul class="genreRecom">
# <li>
# <h4 class="subtlt3">
# <a href="#none" onclick="nclk_v2(event,'Cha.cat','99',1); goSeries('/comic/categoryProductList.series?categoryTypeCode=genre&amp;genreCode=99')" title="새 창">
#
#                             순정
#
#
#
#                     </a><span class="Nico_arr"></span>
# </h4>
# <ul class="genreRecomList">
# <li>
# <div class="genreRecomImg3">
# <a href="#none" onclick="nclk_v2(event,'Cha.thum','422680',1); goSeries('/comic/detail.series?originalProductId=422680')" title="새 창">
# <img alt="남다른 대표님의 사정" height="100" onerror='this.src="https://ssl.pstatic.net/static/comic/images/migration/thumbnail/noimg.gif"' src="https://comicthumb-phinf.pstatic.net/20210118_39/pocket_1610932311541r708l_JPEG/____.jpg?type=m80" title="남다른 대표님의 사정" width="80"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo3">
# <h6 class="title">
# <a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=422680')" title="새 창">남다른 대표님의 사정</a>
# </h6>
# <div class="user">Zhiyin Animation&amp;Leng Yilan&amp;Baishen Animation</div>
# <div class="summary"><a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=422680')" title="새 창">"못 믿겠으면 오늘 밤에 나랑 같이 자 보...</a></div>
# <div class="rating_type">
# <span class="star"><em style="width:86%" title="8.6점">평점</em></span>
# <strong>
#
#                                         8.6
#
#
#                                 </strong>
# </div>
# </div>
# </li>
# <li>
# <div class="genreRecomImg3">
# <a href="#none" onclick="nclk_v2(event,'Cha.thum','421796',1); goSeries('/comic/detail.series?originalProductId=421796')" title="새 창">
# <img alt="이번 생은 악녀로 살겠습니다" height="100" onerror='this.src="https://ssl.pstatic.net/static/comic/images/migration/thumbnail/noimg.gif"' src="https://comicthumb-phinf.pstatic.net/20210107_163/pocket_1610000559987TmlFl_JPEG/image.JPEG?type=m80" title="이번 생은 악녀로 살겠습니다" width="80"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo3">
# <h6 class="title">
# <a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=421796')" title="새 창">이번 생은 악녀로 살겠습니다</a>
# </h6>
# <div class="user">AKE Culture</div>
# <div class="summary"><a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=421796')" title="새 창">계모와 새언니의 계략으로 어머니를 잃고 처...</a></div>
# <div class="rating_type">
# <span class="star"><em style="width:80%" title="8점">평점</em></span>
# <strong>
#
#                                         8
#
#
#                                 </strong>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <h4 class="subtlt3">
# <a href="#none" onclick="nclk_v2(event,'Cha.cat','90',1); goSeries('/comic/categoryProductList.series?categoryTypeCode=genre&amp;genreCode=90')" title="새 창">
#
#
#
#                             소년
#
#                     </a><span class="Nico_arr"></span>
# </h4>
# <ul class="genreRecomList">
# <li>
# <div class="genreRecomImg3">
# <a href="#none" onclick="nclk_v2(event,'Cha.thum','450820',1); goSeries('/comic/detail.series?originalProductId=450820')" title="새 창">
# <img alt="달로 만든 아이" height="100" onerror='this.src="https://ssl.pstatic.net/static/comic/images/migration/thumbnail/noimg.gif"' src="https://comicthumb-phinf.pstatic.net/20220422_190/pocket_1650617386327uURSu_JPEG/�ø���_ǥ��_690x1000.jpg?type=m80" title="달로 만든 아이" width="80"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo3">
# <h6 class="title">
# <a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=450820')" title="새 창">달로 만든 아이</a>
# </h6>
# <div class="user">온윤</div>
# <div class="summary"><a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=450820')" title="새 창">어린 시절부터 남들이 보지 못하는 존재들을...</a></div>
# <div class="rating_type">
# <span class="star"><em style="width:99%" title="9.9점">평점</em></span>
# <strong>
#
#                                         9.9
#
#
#                                 </strong>
# </div>
# </div>
# </li>
# <li>
# <div class="genreRecomImg3">
# <a href="#none" onclick="nclk_v2(event,'Cha.thum','478388',1); goSeries('/comic/detail.series?originalProductId=478388')" title="새 창">
# <img alt="이세계에서 로그아웃하는 방법" height="100" onerror='this.src="https://ssl.pstatic.net/static/comic/images/migration/thumbnail/noimg.gif"' src="https://comicthumb-phinf.pstatic.net/20220801_7/pocket_1659318807574cPSzj_JPEG/�̼��迡��_�α׾ƿ��ϴ�_���_ǥ��(����).jpg?type=m80" title="이세계에서 로그아웃하는 방법" width="80"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo3">
# <h6 class="title">
# <a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=478388')" title="새 창">이세계에서 로그아웃하는 방법</a>
# </h6>
# <div class="user">Neoman</div>
# <div class="summary"><a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=478388')" title="새 창">가상현실게임 '코스모스'에 갇힌 지 1,0...</a></div>
# <div class="rating_type">
# <span class="star"><em style="width:25%" title="2.5점">평점</em></span>
# <strong>
#
#                                         2.5
#
#
#                                 </strong>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <h4 class="subtlt3">
# <a href="#none" onclick="nclk_v2(event,'Cha.cat','88',1); goSeries('/comic/categoryProductList.series?categoryTypeCode=genre&amp;genreCode=88')" title="새 창">
#
#
#                             무협
#
#
#                     </a><span class="Nico_arr"></span>
# </h4>
# <ul class="genreRecomList">
# <li>
# <div class="genreRecomImg3">
# <a href="#none" onclick="nclk_v2(event,'Cha.thum','473889',1); goSeries('/comic/detail.series?originalProductId=473889')" title="새 창">
# <img alt="100만 년 만에 귀환하다" height="100" onerror='this.src="https://ssl.pstatic.net/static/comic/images/migration/thumbnail/noimg.gif"' src="https://comicthumb-phinf.pstatic.net/20220711_85/pocket_1657521180941LxFlP_JPEG/100man.jpg?type=m80" title="100만 년 만에 귀환하다" width="80"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo3">
# <h6 class="title">
# <a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=473889')" title="새 창">100만 년 만에 귀환하다</a>
# </h6>
# <div class="user">삼계동화</div>
# <div class="summary"><a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=473889')" title="새 창">멀고도 아득한 세월, 백만 년.
# 대륙이...</a></div>
# <div class="rating_type">
# <span class="star"><em style="width:90%" title="9점">평점</em></span>
# <strong>
#
#                                         9
#
#
#                                 </strong>
# </div>
# </div>
# </li>
# <li>
# <div class="genreRecomImg3">
# <a href="#none" onclick="nclk_v2(event,'Cha.thum','474263',1); goSeries('/comic/detail.series?originalProductId=474263')" title="새 창">
# <img alt="사상 최강 남주" height="100" onerror='this.src="https://ssl.pstatic.net/static/comic/images/migration/thumbnail/noimg.gif"' src="https://comicthumb-phinf.pstatic.net/20220627_195/pocket_1656299465823gKg0T_JPEG/������_����ְ�����_ǥ��.jpg?type=m80" title="사상 최강 남주" width="80"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="genreRecomInfo3">
# <h6 class="title">
# <a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=474263')" title="새 창">사상 최강 남주</a>
# </h6>
# <div class="user">ruohong</div>
# <div class="summary"><a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=474263')" title="새 창">이세계 무협 세계관에 빙의한 주인공, 조강...</a></div>
# <div class="rating_type">
# <span class="star"><em style="width:70%" title="7점">평점</em></span>
# <strong>
#
#                                         7
#
#
#                                 </strong>
# </div>
# </div>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <!-- // 장르별 인기 유료 만화(업데이트순) -->
# <script type="text/javascript">
#
#     new mainGenreInfo("Update", "omnibus");
#
#     function goSeries(url) {
#         var seriesPopup = window.open("https://series.naver.com" + url, "series", "left=0, top=0, menubar=yes, resizable=yes, scrollbars=yes, status=yes, titlebar=yes, toolbar=yes, directories=yes, location=yes");
#         seriesPopup.focus();
#     }
#
#
#
# </script>
# <script id="webtoonGenreTemplate" type="text/template">
# 	{for num:record in mainGenreList}
# 	<li>
# 		<div class="genreRecomImg2">
# 			<a onclick="nclk_v2(event,'rcn*{=nCkicksValue}.thum','{=record.titleId}','{=num + 1}')" href="/webtoon/list?titleId={=record.titleId}">
# 				<span class="mask"></span>
# 				<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'"
# 					 src="https://shared-comic.pstatic.net/thumb/webtoon{=record.thumbnailFilepath}{=record.thumbnailFilename}"
# 					 width="218" height="120" title="{=record.titleName}" alt="{=record.titleName}">
# 				{if record.finished == 'Y'}<span class="finish">완결</span>{/if}
# 				{if record.ageRate == 'RATE_18'}<span class="mark_adult_thumb">18세 이상 이용 가능</span>{/if}
# 			</a>
# 		</div>
# 		<div class="genreRecomInfo2">
# 			<h6 class="title">
# 				{if record.restYN == 'Y'}<span class="ico_break">휴재</span>{/if}
# 				{if record.webtoonViewerType == 'CUTTOON'}<span class="ico_cut">컷툰</span>{/if}
# 				{if record.webtoonViewerType == 'SHORTANI'}<span class="ico_short_ani">숏애니</span>{/if}
# 				<a onclick="nclk_v2(event,'rcn*{=nCkicksValue}.title','{=record.titleId}','{=num + 1}')" href="/webtoon/list?titleId={=record.titleId}">
# 					<span>{=record.titleName}</span>
# 				</a>
# 			</h6>
# 			<p>
# 				<a onclick="nclk_v2(event,'rcn*{=nCkicksValue}.sub','{=record.titleId}','{=num + 1}')" href="/webtoon/detail?titleId={=record.titleId}&no={=record.no}">
# 					<span>{=record.subTitle}</span>
# 				</a>
# 			</p>
# 			<span class="user">
# 			<a href="#" onclick="return goArtist('{=record.titleId}', '{=num + 1}', this, event);">
# 				{=record.painterIdBy28}
# 			</a>
# 		</span>
# 		</div>
# 	</li>
# 	{/for}
# </script>
# </div>
# <!-- side menu -->
# <div id="aside">
# <!-- 배너 -->
# <div class="asideAd" data-veta-preview="p_wtoon_home" id="barAndRightAd" name="addiv"></div>
# <script>
#             if (navigator.userAgent.toLowerCase().indexOf("msie") === -1) {
#                 const script = document.createElement('script');
#                 script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#                 document.head.appendChild(script);
#                 window.gladsdk = window.gladsdk || { cmd: [] };
#                 gladsdk.cmd.push(function() {
#                     gladsdk.defineAdSlot({
#                         adUnitId: "p_webtoon_right",
#                         adSlotElementId: "barAndRightAd",
#                     });
#                     gladsdk.displayAd("barAndRightAd");
#                 });
#             }
#         </script>
# <!-- //배너 -->
# <div class="asideButton upload">
# <a class="Nbtn_upload" href="/mypage/myActivity" onclick="nclk_v2(event,'olk.upload');">웹툰 올리기</a>
# </div>
# <!-- 롤링이미지 -->
# <div class="asideRolling">
# <a href="https://comic.naver.com/webtoon/list.nhn?titleId=798622" onclick="nclk_v2(event,'olk.banner')">
# <img alt="하늘액션 서바이벌 &lt;천상의 주인&gt;" height="97" src="https://naverwebtoon-phinf.pstatic.net/20220804_122/1659610289124L28k3_JPEG/upload_8810259802340215116.JPEG?type=p100" width="240"/>
# </a>
# </div>
# <!-- 인기급상승웹툰 -->
# <div class="asideBox">
# <h4 class="asideBoxTitle"><img alt="인기급상승웹툰" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/common/subtlt_r_best_v2.gif" title="인기급상승웹툰" width="78"/></h4>
# <div>
# <ul class="asideBoxTab"><!-- 선택된 메뉴에는 choice라는 클래스명을 사용합니다 -->
# <li class="choice" id="realTimeRankChoiceTabFavorite"><a href="#" id="realTimeRankChoiceTabFavoriteClick" onclick="nclk_v2(event,'rnk.rep')"><img alt="인기순" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_favor.gif" title="인기순" width="31"/></a></li>
# <li id="realTimeRankChoiceTabUpdate"><a href="#" id="realTimeRankChoiceTabUpdateClick" onclick="nclk_v2(event,'rnk.upd')"><img alt="업데이트순" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_update.gif" title="업데이트순" width="52"/></a></li>
# </ul>
# <h3 class="blind" id="realTimeRankBlindName">인기순</h3>
# <ol class="asideBoxRank" id="realTimeRankFavorite">
# <li class="rank01">
# <a href="/webtoon/detail?titleId=783053&amp;no=41" onclick="nclk_v2(event,'rnk*p.cont','783053','1')" title="김부장-41화 우리집에 국수 먹으러 갈래?">김부장-41화 우리집에 국수 먹으러 갈래?</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank02">
# <a href="/webtoon/detail?titleId=703846&amp;no=224" onclick="nclk_v2(event,'rnk*p.cont','703846','2')" title="여신강림-219화">여신강림-219화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank03">
# <a href="/webtoon/detail?titleId=784248&amp;no=42" onclick="nclk_v2(event,'rnk*p.cont','784248','3')" title="내가 키운 S급들-42화 : 위기의 명우!">내가 키운 S급들-42화 : 위기의 명우!</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank04">
# <a href="/webtoon/detail?titleId=789979&amp;no=28" onclick="nclk_v2(event,'rnk*p.cont','789979','4')" title="멸망 이후의 세계-제 27 화">멸망 이후의 세계-제 27 화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank05">
# <a href="/webtoon/detail?titleId=738174&amp;no=129" onclick="nclk_v2(event,'rnk*p.cont','738174','5')" title="중증외상센터 : 골든 아워-2부 64화 : 초응급">중증외상센터 : 골든 아워-2부 64화 : 초응급</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank06">
# <a href="/webtoon/detail?titleId=796152&amp;no=9" onclick="nclk_v2(event,'rnk*p.cont','796152','6')" title="마루는 강쥐-9화. 마트에 가자! ">마루는 강쥐-9화. 마트에 가자!</a>
# <span class="rankBox">
# <img alt="순위상승" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_up.gif" title="순위상승" width="7"/>2
#
#
#
# 				</span>
# </li>
# <li class="rank07">
# <a href="/webtoon/detail?titleId=702608&amp;no=244" onclick="nclk_v2(event,'rnk*p.cont','702608','7')" title="랜덤채팅의 그녀!-244. 안티테제">랜덤채팅의 그녀!-244. 안티테제</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank08">
# <a href="/webtoon/detail?titleId=773459&amp;no=62" onclick="nclk_v2(event,'rnk*p.cont','773459','8')" title="용사가 돌아왔다-62화 이성준(1)">용사가 돌아왔다-62화 이성준(1)</a>
# <span class="rankBox">
# <img alt="순위하락" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_down.gif" title="순위하락" width="7"/>2
#
#
#
#
# 				</span>
# </li>
# <li class="rank09">
# <a href="/webtoon/detail?titleId=773522&amp;no=46" onclick="nclk_v2(event,'rnk*p.cont','773522','9')" title="1을 줄게-46화">1을 줄게-46화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank10">
# <a href="/webtoon/detail?titleId=790713&amp;no=47" onclick="nclk_v2(event,'rnk*p.cont','790713','10')" title="대학원 탈출일지-46화-식사(2)">대학원 탈출일지-46화-식사(2)</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# </ol>
# <ol class="asideBoxRank" id="realTimeRankUpdate" style="display:none;">
# <li class="rank01">
# <a href="/webtoon/detail?titleId=711422&amp;no=408" onclick="nclk_v2(event,'rnk*u.cont','711422','1')" title="삼국지톡-입촉_14. 빠릿빠릿한 신입, 사마의">
#
# 					삼국지톡-입촉_14. 빠릿빠릿한 신입, 사마의
# 				</a>
# <span class="timeBox">
#
#
#
# 							19시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank02">
# <a href="/webtoon/detail?titleId=732988&amp;no=137" onclick="nclk_v2(event,'rnk*u.cont','732988','2')" title="올가미-137화">
#
# 					올가미-137화
# 				</a>
# <span class="timeBox">
#
#
#
# 							19시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank03">
# <a href="/webtoon/detail?titleId=752532&amp;no=92" onclick="nclk_v2(event,'rnk*u.cont','752532','3')" title="연우의 순정-92화">
#
# 					연우의 순정-92화
# 				</a>
# <span class="timeBox">
#
#
#
# 							19시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank04">
# <a href="/webtoon/detail?titleId=775328&amp;no=58" onclick="nclk_v2(event,'rnk*u.cont','775328','4')" title="다꾸남-마지막화 다이어리">
#
# 					다꾸남-마지막화 다이어리
# 				</a>
# <span class="timeBox">
#
#
#
# 							19시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank05">
# <a href="/webtoon/detail?titleId=773522&amp;no=46" onclick="nclk_v2(event,'rnk*u.cont','773522','5')" title="1을 줄게-46화">
#
# 					1을 줄게-46화
# 				</a>
# <span class="timeBox">
#
#
#
# 							19시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank06">
# <a href="/webtoon/detail?titleId=676695&amp;no=304" onclick="nclk_v2(event,'rnk*u.cont','676695','6')" title="제로게임-[301] 값어치">
#
# 					제로게임-[301] 값어치
# 				</a>
# <span class="timeBox">
#
#
#
# 							19시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank07">
# <a href="/webtoon/detail?titleId=753839&amp;no=99" onclick="nclk_v2(event,'rnk*u.cont','753839','7')" title="빅맨-99화">
#
# 					빅맨-99화
# 				</a>
# <span class="timeBox">
#
#
#
# 							19시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank08">
# <a href="/webtoon/detail?titleId=771018&amp;no=69" onclick="nclk_v2(event,'rnk*u.cont','771018','8')" title="찐:종합게임동아리-69화">
#
# 					찐:종합게임동아리-69화
# 				</a>
# <span class="timeBox">
#
#
#
# 							19시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank09">
# <a href="/webtoon/detail?titleId=766966&amp;no=59" onclick="nclk_v2(event,'rnk*u.cont','766966','9')" title="태시트-59화">
#
# 					태시트-59화
# 				</a>
# <span class="timeBox">
#
#
#
# 							19시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank10">
# <a href="/webtoon/detail?titleId=784518&amp;no=44" onclick="nclk_v2(event,'rnk*u.cont','784518','10')" title="대공님, 실수였어요!-44화">
#
# 					대공님, 실수였어요!-44화
# 				</a>
# <span class="timeBox">
#
#
#
# 							19시간전
#
#
#
#
#
# 				</span>
# </li>
# </ol>
# </div>
# </div>
# <!-- //인기급상승웹툰 -->
# <!-- 추천 웹툰 -->
# <div class="asideBox">
# <!-- [D] 10대: h_10_v2.gif, 20대: h_20_v2.gif -->
# <h4 class="asideBoxTitle"><img alt="30대 인기웹툰" height="11" id="recommand_ageImg" src="https://ssl.pstatic.net/static/comic/images/migration/common/h_30_v2.gif" width="107"/>
# <div class="tab_nv">
# <a class="Nico_prv" href="#" id="recommandWebtoonRankLeftTabClick">이전</a><a class="Nico_nxt" href="#" id="recommandWebtoonRankRightTabClick">다음</a>
# </div>
# </h4>
# <div>
# <ul class="asideBoxTab">
# <li class="choice" id="recommandWebtoonRankMTabOver"><a href="#" onclick="return false;"> <img alt="남자" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_m.png" title="남자" width="21"/></a></li>
# <li id="recommandWebtoonRankWTabOver"><a href="#" onclick="return false;"> <img alt="여자" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_w.png" title="여자" width="21"/></a></li>
# </ul>
# <h3 class="blind" id="ageGenderRankBlindName">남자</h3>
# <ol class="asideBoxRank asideBoxRank2" id="recommandWebtoonRank">
# <li class="rank01" id="recommandLi_0">
# <div class="thumb6">
# <a href="/webtoon/detail?titleId=789979&amp;no=28" id="recommand_link_0" title="멸망 이후의 세계">
# <img alt="멸망 이후의 세계" height="33" id="recommand_thumbnail_0" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/789979/thumbnail/thumbnail_IMAG10_e5197e49-c571-46c0-8760-535fa24b0f2d.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail?titleId=789979&amp;no=28" id="recommand_titleName_0" title="멸망 이후의 세계">멸망 이후의 세계</a>
# <em><a href="#" id="recommand_painter_0" onclick="return artistAction.viewArtist('789979', this);" title="S-Cynan / 언데드 감자 / 싱숑">S-Cynan / 언데드 감자 / 싱숑</a></em>
# <span class="rankBox2">
# <img alt="변동없음" id="recommand_img_0" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음"/><em id="recommand_rank_0">0</em>
# </span>
# </div>
# </li>
# <li class="rank02" id="recommandLi_1">
# <div class="thumb6">
# <a href="/webtoon/detail?titleId=702608&amp;no=244" id="recommand_link_1" title="랜덤채팅의 그녀!">
# <img alt="랜덤채팅의 그녀!" height="33" id="recommand_thumbnail_1" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/702608/thumbnail/thumbnail_IMAG10_bf04b076-5a8e-4ac7-ba97-38ca0197d7ee.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail?titleId=702608&amp;no=244" id="recommand_titleName_1" title="랜덤채팅의 그녀!">랜덤채팅의 그녀!</a>
# <em><a href="#" id="recommand_painter_1" onclick="return artistAction.viewArtist('702608', this);" title="박은혁">박은혁</a></em>
# <span class="rankBox2">
# <img alt="순위하락" id="recommand_img_1" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_up.gif" title="순위상승"/><em id="recommand_rank_1">1</em>
# </span>
# </div>
# </li>
# <li class="rank03" id="recommandLi_2">
# <div class="thumb6">
# <a href="/webtoon/detail?titleId=773459&amp;no=62" id="recommand_link_2" title="용사가 돌아왔다">
# <img alt="용사가 돌아왔다" height="33" id="recommand_thumbnail_2" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/773459/thumbnail/thumbnail_IMAG10_993cd8aa-aaa9-4fbb-96db-1653e6bdadc4.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail?titleId=773459&amp;no=62" id="recommand_titleName_2" title="용사가 돌아왔다">용사가 돌아왔다</a>
# <em><a href="#" id="recommand_painter_2" onclick="return artistAction.viewArtist('773459', this);" title="나락 / 풍백">나락 / 풍백</a></em>
# <span class="rankBox2">
# <img alt="순위하락" id="recommand_img_2" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_down.gif" title="순위하락"/><em id="recommand_rank_2">1</em>
# </span>
# </div>
# </li>
# <li class="rank04" id="recommandLi_3">
# <div class="thumb6">
# <a href="/webtoon/detail?titleId=798326&amp;no=2" id="recommand_link_3" title="시체기사 군터">
# <img alt="시체기사 군터" height="33" id="recommand_thumbnail_3" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/798326/thumbnail/thumbnail_IMAG10_d63ebf95-a6d1-427f-9e2d-070880410e78.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail?titleId=798326&amp;no=2" id="recommand_titleName_3" title="시체기사 군터">시체기사 군터</a>
# <em><a href="#" id="recommand_painter_3" onclick="return artistAction.viewArtist('798326', this);" title="마요너구리">마요너구리</a></em>
# <span class="rankBox2">
# <img alt="순위하락" id="recommand_img_3" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_up.gif" title="순위상승"/><em id="recommand_rank_3">1</em>
# </span>
# </div>
# </li>
# <li class="rank05" id="recommandLi_4">
# <div class="thumb6">
# <a href="/webtoon/detail?titleId=774358&amp;no=34" id="recommand_link_4" title="천마는 평범하게 살 수 없다">
# <img alt="천마는 평범하게 살 수 없다" height="33" id="recommand_thumbnail_4" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/774358/thumbnail/thumbnail_IMAG10_c6d972c8-8543-4adc-b1ea-e7ac42f5f975.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail?titleId=774358&amp;no=34" id="recommand_titleName_4" title="천마는 평범하게 살 수 없다">천마는 평범하게 살 수 없다</a>
# <em><a href="#" id="recommand_painter_4" onclick="return artistAction.viewArtist('774358', this);" title="철범 / 우푸 / 산천">철범 / 우푸 / 산천</a></em>
# <span class="rankBox2">
# <img alt="순위하락" id="recommand_img_4" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_down.gif" title="순위하락"/><em id="recommand_rank_4">1</em>
# </span>
# </div>
# </li>
# </ol>
# </div>
# </div>
# <script>
# new naver.comic.RecommandWebtoonRankLayer(1, "https://shared-comic.pstatic.net/thumb");
# </script>
# <!-- //추천 웹툰 -->
# <!-- 공지사항 -->
# <div class="asideBox">
# <h4 class="asideBoxTitle">
# <img alt="공지사항" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/subtlt_r_notice.gif" title="공지사항" width="43"/>
# </h4>
# <ul class="asideBoxNotice">
# <li>
# <a href="/notice/detail?noticeId=1695" onclick="nclk_v2(event,'sna.not','1695','1')" title="2022 지상최대공모전 웹툰부문 1기 수상작 발표">
# <strong>
# 					2022 지상최대공모전 웹툰부문 1기 수상작 발표
# 				</strong>
# </a>
# </li>
# <li>
# <a href="/notice/detail?noticeId=1690" onclick="nclk_v2(event,'sna.not','1690','2')" title="2022 학원로맨스 웹툰 모집 안내 (7/14~8/24)">
# <strong>
# 					2022 학원로맨스 웹툰 모집 안내
# 				</strong>
# </a>
# </li>
# <li>
# <a href="/notice/detail?noticeId=1686" onclick="nclk_v2(event,'sna.not','1686','3')" title="2022 네이버웹툰 최강자전 개최 안내">
# <strong>
# 					2022 네이버웹툰 최강자전 개최 안내
# 				</strong>
# </a>
# </li>
# <li>
# <a href="/notice/detail?noticeId=1676" onclick="nclk_v2(event,'sna.not','1676','4')" title="2022 지상최대공모전 웹툰 부문 상세 공지">
# <strong>
# 					2022 지상최대공모전 웹툰 부문 상세 공지
# 				</strong>
# </a>
# </li>
# <li>
# <a href="/notice/detail?noticeId=535" onclick="nclk_v2(event,'sna.not','535','5')" title="(new) 웹소설원작 웹툰을 위한 각색/작화 작가를 모십니다!">
#
# 					웹소설원작 웹툰을 위한 각색/작화 작가를 모십니다
#
# 			</a>
# </li>
# <li>
# <a href="/notice/detail?noticeId=495" onclick="nclk_v2(event,'sna.not','495','6')" title="(new) 네이버웹툰 연재 작가를 모십니다! ">
#
# 					네이버웹툰 연재 작가를 모십니다
#
# 			</a>
# </li>
# <li>
# <a href="/notice/detail?noticeId=521" onclick="nclk_v2(event,'sna.not','521','7')" title="[출시] 새로운 웹툰 라인업! &lt;매일+&gt;에서 만나보세요! ">
#
# 					[출시] 새로운 웹툰 라인업! &lt;매일+&gt;
#
# 			</a>
# </li>
# <li>
# <a href="/notice/detail?noticeId=526" onclick="nclk_v2(event,'sna.not','526','8')" title="#내돈내툰, 우리가 웹툰을 즐기는 방법">
#
# 					#내돈내툰, 우리가 웹툰을 즐기는 방법
#
# 			</a>
# </li>
# <li>
# <a href="/notice/detail?noticeId=1697" onclick="nclk_v2(event,'sna.not','1697','9')" title="2022년 8월 유료화 전환 작품 안내">
#
# 					2022년 8월 유료화 전환 작품 안내
#
# 			</a>
# </li>
# </ul>
# <a class="asideBoxMore" href="/notice/list" onclick="nclk_v2(event,'sna.more')">
# <span class="blind">공지사항</span> 더보기
# 	</a>
# </div>
# <!-- //공지사항 -->
# <div class="asideBanner">
# <a href="/business/proposalGuide" onclick="nclk_v2(event,'sna.proposal');">
# <img alt="웹툰, 웹소설 온라인 광고 판권 사업" height="86" src="https://ssl.pstatic.net/static/comic/images/bnr_partnership.jpg" width="240"/>
# </a>
# </div>
# <div class="asideBanner">
# <a href="https://joinus.comic.naver.com" onclick="nclk_v2(event,'sna.writerproposal');">
# <img alt="연재 경력 작가 웹툰 차기작 제안" height="86" src="https://ssl.pstatic.net/static/comic/images/bnr_joinus.jpg" width="240"/>
# </a>
# </div>
# <div class="asideBanner">
# <a href="https://comic.naver.com/contest/greatest/webtoon">
# <img alt="2022 지상최대공모전 - 접수 및 안내" height="86" src="https://ssl.pstatic.net/static/comic/images/bnr_contest_2022.jpg" width="240"/>
# </a>
# </div>
# <div class="asideBanner">
# <a href="https://recruit.webtoonscorp.com" onclick="nclk_v2(event,'sna.recruit');">
# <img alt="웹툰 채용공고 CAREERS" height="86" src="https://ssl.pstatic.net/static/comic/images/bnr_careers.jpg" width="240"/>
# </a>
# </div>
# <div class="asideButton">
# <a class="btn_faq" href="https://help.naver.com/support/service/main.help?serviceNo=799" onclick="nclk_v2(event,'sna.faq')" target="_blank" title="새 창">
# <span class="blind">웹툰 고객센터</span>
# </a>
# </div>
# </div>
# </div>
# <!-- Footer -->
# <!-- FOOTER Start -->
# <div id="footer">
# <div class="list_link">
# <ul>
# <li class="link_site webtoon"><a href="/index" onclick="nclk_v2(event,'fot.webtoon')"><span class="blind">웹툰</span></a></li>
# <li class="link_site novel"><a href="https://novel.naver.com" onclick="nclk_v2(event,'fot.novel')"><span class="blind">웹소설</span></a></li>
# <li class="link_site series"><a href="https://series.naver.com" onclick="nclk_v2(event,'fot.series')"><span class="blind">시리즈 <span>소설·만화</span></span></a></li>
# <li class="link_site serieson"><a href="https://serieson.naver.com" onclick="nclk_v2(event,'fot.serieson')"><span class="blind">시리즈온 <span>영화·방송</span></span></a></li>
# </ul>
# </div>
# <div class="corp_info">
# <div class="webtoon_corp_info">
# <ul>
# <li><a href="https://member.webtoon.naver.com/policies/terms/" onclick="nclk_v2(event,'fot.wagreement')" target="_blank">네이버웹툰 이용약관</a></li>
# <li><a href="https://m.comic.naver.com/store/comic/common/passJoinAgreeContract" onclick="nclk_v2(event,'fot.cooterms')" target="_blank">전용상품권 이용약관</a></li>
# <li><a class="privacy" href="https://member.webtoon.naver.com/policies/privacy/" onclick="nclk_v2(event,'fot.wprivacy')" target="_blank">개인정보처리방침</a></li>
# <li><a href="https://member.webtoon.naver.com/policies/youthpolicy/" onclick="nclk_v2(event,'fot.youthpolicy')" target="_blank">청소년보호정책</a></li>
# <li><a href="https://help.naver.com/support/service/main.help?serviceNo=799" onclick="nclk_v2(event,'fot.whelp')" target="_blank">웹툰 고객센터</a></li>
# </ul>
# <ul>
# <li><a href="/business/proposalGuide" onclick="nclk_v2(event,'fot.proposal')" target="_blank">광고<span class="dot">·</span>사업문의</a></li>
# </ul>
# <address><a class="webtoon_corp_link" href="https://webtoonscorp.com" onclick="nclk_v2(event,'fot.wtcorp');" target="_blank"><span class="blind">ⓒ NAVER WEBTOON Limited</span></a></address>
# </div>
# <div class="naver_corp_info">
# <ul>
# <li><a href="https://www.naver.com/rules/service.html" onclick="nclk_v2(event,'fot.agreement')" target="_blank">이용약관</a></li>
# <li><a class="privacy" href="https://www.naver.com/rules/privacy.html" onclick="nclk_v2(event,'fot.privacy')" target="_blank">개인정보처리방침</a></li>
# <li><a href="https://www.naver.com/rules/disclaimer.html" onclick="nclk_v2(event,'fot.disclaimer')" target="_blank">책임의 한계와 법적고지</a></li>
# <li><a href="https://help.naver.com/support/home.help?serviceNo=799" onclick="nclk_v2(event,'fot.helpdesk')" target="_blank" title="새 창">고객센터</a></li>
# <li><a href="https://help.pay.naver.com/mail/form.help?alias=checkout_accuse" onclick="nclk_v2(event,'fot.claim')" target="_blank">결제도용신고</a></li>
# </ul>
# <ul>
# <li><a href="https://cpc.naver.com/cpc/index.nhn" onclick="nclk_v2(event,'fot.cpclaim')" target="_blank">저작권침해신고</a></li>
# </ul>
# <address><a href="https://www.navercorp.com/" onclick="nclk_v2(event,'fot.navercorp')" target="_blank"><span class="naver_corp_link"><span class="blind">ⓒ NAVER CORP.</span></span></a></address>
# </div>
# </div>
# <ul class="company_info">
# <li>사업자등록번호 669-86-01888</li>
# <li>통신판매업 신고번호 2020-성남분당B-0719 <a href="https://www.ftc.go.kr/bizCommPop.do?wrkr_no=6698601888" target="_blank">(사업자정보확인)</a></li>
# <li>대표이사 김준구</li>
# <li>호스팅사업자 네이버비즈니스플랫폼</li>
# </ul>
# <ul class="company_info">
# <li>주소 경기도 성남시 분당구 분당내곡로 131 판교테크원 타워1, 11-12층</li>
# <li>고객센터 1588-3820</li>
# <li>이메일 <a href="mailto:ccnaver@naver.com">ccnaver@naver.com</a></li>
# </ul>
# <p class="copyright_law">모든 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단으로 이용하는 경우 관련 법령에 따라 법적 책임을 질 수 있습니다.</p>
# </div>
# <!-- //FOOTER End -->
# </div>
# <script type="text/javascript">
# 			var agent = navigator.userAgent.toLowerCase();
#
# 			function loadEvent(){
# 				try{
# 					getGNB();
# 				}catch(ex){
#
# 				}
# 				new naver.comic.RealtimeRankLayer();
# 				if ( $("uploadLinkId") ){
# 					$Fn(function(oEvent) {
# 						oEvent.stop();
# 						if ("true" != "false") {
# 							if (!confirm('로그인해야 이용할 수 있습니다. 로그인 하겠습니까?'))
# 								return false;
# 							else {
# 								location.href = "https://nid.naver.com/nidlogin.login?mode=form&url="
# 										+ encodeURIComponent("https://" + location.host
# 												+ "/upload/upload");
# 								return;
# 							}
# 						}
# 						location.href = "/upload/upload";
# 						return true;
# 					}).attach($("uploadLinkId"),"click");
# 				}
# 				naver.comic.oArtistAction = new naver.comic.Artist();
# 				artistAction = naver.comic.oArtistAction;
# 				naver.comic.oSearchBar = new naver.comic.SearchBarOptionActHandler();
#
# 				// GNB 이벤트 재정의.
# 				$Fn(function(oEvent){
# 					var aWtChild = $Element("gnb" ).child(function (v){return true;});
# 					var wtSrc = $Element(oEvent.element);
# 					var bContain = false;
# 					for (var i = 0 ; i < aWtChild.length ;i++){
# 						if ( aWtChild[i].$value() == wtSrc.$value()){
# 							bContain = true;
# 							break;
# 						}
# 					}
# 					if ( !bContain && gnbAllLayerClose ){
# 						gnbAllLayerClose();
#
# 					}
#
# 				}).attach(document,"click");
# 			}
# 			$Fn(loadEvent).attach(window,'load');
# 		</script>
# <script src="/aggregate/javascript/release/lcslog_20220803135648.js" type="text/javascript"></script>
# <script type="text/javascript">
#     try {
#         var eventType = "onpageshow" in window ? "onpageshow" : "onload";
#         var oldEvent = window[eventType];
#         window[eventType] = function() {
#             if (oldEvent) {
#                 oldEvent();
#             }
#             lcs_do();
#         };
#     } catch(ex) { }
# </script>
# </body>
# </html>

# %% [markdown]
# # 네이버 웹툰 인기순위 웹스크래핑

# %% [markdown]
# - 인기순

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

res_comic = requests.get('https://comic.naver.com/index')
soup_comic = BeautifulSoup(res_comic.text, 'lxml')

comic_all = soup_comic.find('ol', attrs = {'id': 'realTimeRankFavorite'}).find_all('li')

list_comic_all = []

for rank, comic in enumerate(comic_all):
  list_comic = []
  list_comic.append(rank + 1)
  list_comic.append(comic.a.text.strip())
  list_comic.append('https://comic.naver.com' + comic.a['href'])
  list_comic_all.append(list_comic)

df_comic = pd.DataFrame(list_comic_all, columns = ['순위', '제목', '링크'])

df_comic
# Out:
#    순위                           제목  \
# 0   1      김부장-41화 우리집에 국수 먹으러 갈래?
# 1   2                    여신강림-219화
# 2   3      내가 키운 S급들-42화 : 위기의 명우!
# 3   4             멸망 이후의 세계-제 27 화
# 4   5  중증외상센터 : 골든 아워-2부 64화 : 초응급
# 5   6           마루는 강쥐-9화. 마트에 가자!
# 6   7          랜덤채팅의 그녀!-244. 안티테제
# 7   8          용사가 돌아왔다-62화 이성준(1)
# 8   9                    1을 줄게-46화
# 9  10           대학원 탈출일지-46화-식사(2)
#
#                                                   링크
# 0  https://comic.naver.com/webtoon/detail?titleId...
# 1  https://comic.naver.com/webtoon/detail?titleId...
# 2  https://comic.naver.com/webtoon/detail?titleId...
# 3  https://comic.naver.com/webtoon/detail?titleId...
# 4  https://comic.naver.com/webtoon/detail?titleId...
# 5  https://comic.naver.com/webtoon/detail?titleId...
# 6  https://comic.naver.com/webtoon/detail?titleId...
# 7  https://comic.naver.com/webtoon/detail?titleId...
# 8  https://comic.naver.com/webtoon/detail?titleId...
# 9  https://comic.naver.com/webtoon/detail?titleId...

# %% [markdown]
# # 영화 리뷰 스크래핑

# %% [markdown]
# - 네이버 영화 리뷰
# - CSV 파일에 저장

# %%
from bs4 import BeautifulSoup
import requests
import time
import csv

need_reviews_cnt = 1000
reviews = []
review_data = []

# page를 1부터 1씩 증가하며 URL을 다음 페이지로 바꿈
for page in range(1, 500):
  url = f'https://movie.naver.com/movie/point/af/list.naver?&page={page}'

  # get: request로 url의 html 문서의 내용 요청
  html = requests.get(url)

  # html을 받아온 문서를 content로 지정 후 soup 객체로 변환
  soup = BeautifulSoup(html.content, 'html.parser')

  # find_all: 지정한 태그의 내용을 모두 찾아 리스트로 변환
  reviews = soup.find_all('td', {'class':'title'})

  # 한 페이지의 리뷰 리스트의 리뷰를 하나씩 보면서 데이터 추출
  for review in reviews:
    sentence = review.find('a', {'class':'report'}).get('onclick').split("', ")[2]

    # 만약 리뷰 내용이 비어있다면 데이터를 사용하지 않음
    if sentence != '':
      movie = review.find('a', {'class':'movie color_b'}).get_text()
      score = review.find('em').get_text()
      review_data.append([movie, sentence, int(score)])
      need_reviews_cnt -= 1

    # 현재까지 수집된 리뷰가 목표 수집 리뷰보다 많아진 경우 크롤링 중지
    if need_reviews_cnt < 0:
      break

    # 다음 페이지를 조회하기 전 0.5초 시간 차를 두기
    time.sleep(0.5)

columns_name = ['movie', 'sentence', 'score']

with open ('samples.csv', 'w', newline = '', encoding = 'utf8') as f:
  write = csv.writer(f)
  write.writerow(columns_name)
  write.writerows(review_data)
